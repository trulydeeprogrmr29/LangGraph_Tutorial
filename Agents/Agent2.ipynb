# %%
from typing import List,TypedDict

from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    values:List[str]
    name:str
    result:str

# %% [markdown]
# we are  handling multiple inputs

# %%
def process_values(state:AgentState) -> AgentState:
    """This function handles multiple different inputs and processes them."""
    processed_values = [value.upper() for value in state['values']]
    state['result'] = ','.join(processed_values)
    return state
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 def process_values(state:AgentState) -> AgentState:
#       2     """This function handles multiple different inputs and processes them."""
#       3     processed_values = [value.upper() for value in state['values']]
#
# NameError: name 'AgentState' is not defined
